# %%
# %cd ..

from src.data_preprocessing import load_data, clean_data, scale_data
from src.feature_engineering import create_features, select_features
from src.utils import save_data, print_dataframe_info
# Out:
# C:\Data-Science\07. Data Science Project Architecture
# C:\testenv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ### Load the data

# %%
data_path = "data/asthma_disease_data.csv"
df = load_data(data_path)
df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          5034   63       0          1               0  15.848744        0
# 1          5035   26       1          2               2  22.757042        0
# 2          5036   57       0          2               1  18.395396        0
# 3          5037   40       1          2               1  38.515278        0
# 4          5038   61       0          0               3  19.283802        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2387       7421   43       1          0               2  29.059613        0
# 2388       7422   18       1          0               1  20.740850        0
# 2389       7423   54       0          3               2  37.079560        0
# 2390       7424   46       1          0               2  23.444712        0
# 2391       7425   26       1          0               0  28.123021        1
#
# ...

# %% [markdown]
# ### Clean the data

# %%
df = clean_data(df)
df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          5034   63       0          1               0  15.848744        0
# 1          5035   26       1          2               2  22.757042        0
# 2          5036   57       0          2               1  18.395396        0
# 3          5037   40       1          2               1  38.515278        0
# 4          5038   61       0          0               3  19.283802        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2387       7421   43       1          0               2  29.059613        0
# 2388       7422   18       1          0               1  20.740850        0
# 2389       7423   54       0          3               2  37.079560        0
# 2390       7424   46       1          0               2  23.444712        0
# 2391       7425   26       1          0               0  28.123021        1
#
# ...

# %% [markdown]
# ### Create new features

# %%
df = create_features(df)
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'PollutionExposure', 'PollenExposure', 'DustExposure', 'PetAllergy',
#        'FamilyHistoryAsthma', 'HistoryOfAllergies', 'Eczema', 'HayFever',
#        'GastroesophagealReflux', 'LungFunctionFEV1', 'LungFunctionFVC',
#        'Wheezing', 'ShortnessOfBreath', 'ChestTightness', 'Coughing',
#        'NighttimeSymptoms', 'ExerciseInduced', 'Diagnosis', 'DoctorInCharge',
#        'BMI_Age', 'High_BMI'],
#       dtype='object')

# %% [markdown]
# ### Select specific features (example: all features in this case)

# %%
selected_features = ['Gender', 'SleepQuality', 'DustExposure'] 
df_selected_features = select_features(df, selected_features)
df_selected_features
# Out:
#       Gender  SleepQuality  DustExposure
# 0          0      8.701003      0.974339
# 1          1      5.153966      6.584631
# 2          0      6.840647      5.445799
# 3          1      4.253036      3.965316
# 4          0      9.625799      8.260605
# ...      ...           ...           ...
# 2387       1      8.300960      3.425445
# 2388       1      7.731192      6.467701
# 2389       0      7.483521      9.484013
# 2390       1      6.717272      5.051405
# 2391       1      8.512253      5.064317
#
# [2392 rows x 3 columns]

# %% [markdown]
# ### Scale the data

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'PollutionExposure', 'PollenExposure', 'DustExposure', 'PetAllergy',
#        'FamilyHistoryAsthma', 'HistoryOfAllergies', 'Eczema', 'HayFever',
#        'GastroesophagealReflux', 'LungFunctionFEV1', 'LungFunctionFVC',
#        'Wheezing', 'ShortnessOfBreath', 'ChestTightness', 'Coughing',
#        'NighttimeSymptoms', 'ExerciseInduced', 'Diagnosis', 'DoctorInCharge',
#        'BMI_Age', 'High_BMI'],
#       dtype='object')

# %%
df_modifyed = df.drop('DoctorInCharge', axis=1)
df = scale_data(df_modifyed)
df
# Out:
#       PatientID       Age    Gender  Ethnicity  EducationLevel       BMI  \
# 0     -1.731327  0.965740 -0.986710   0.334986       -1.455673 -1.582769
# 1     -1.729879 -0.747054  1.013469   1.349273        0.771363 -0.623300
# 2     -1.728430  0.687989 -0.986710   1.349273       -0.342155 -1.229074
# 3     -1.726982 -0.098970  1.013469   1.349273       -0.342155  1.565307
# 4     -1.725534  0.873156 -0.986710  -0.679301        1.884880 -1.105686
# ...         ...       ...       ...        ...             ...       ...
# 2387   1.725534  0.039905  1.013469  -0.679301        0.771363  0.252042
# 2388   1.726982 -1.117388  1.013469  -0.679301       -0.342155 -0.903322
# 2389   1.728430  0.549114 -0.986710   2.363560        0.771363  1.365905
# 2390   1.729879  0.178780  1.013469  -0.679301        0.771363 -0.527792
# 2391   1.731327 -0.747054  1.013469  -0.679301       -1.455673  0.121962
#
#        Smoking  PhysicalActivity  DietQuality  SleepQuality  ...  \
# ...

# %% [markdown]
# ### Final inspection

# %%
print_dataframe_info(df)
# Out:
#    PatientID       Age    Gender  Ethnicity  EducationLevel       BMI  \
# 0  -1.731327  0.965740 -0.986710   0.334986       -1.455673 -1.582769
# 1  -1.729879 -0.747054  1.013469   1.349273        0.771363 -0.623300
# 2  -1.728430  0.687989 -0.986710   1.349273       -0.342155 -1.229074
# 3  -1.726982 -0.098970  1.013469   1.349273       -0.342155  1.565307
# 4  -1.725534  0.873156 -0.986710  -0.679301        1.884880 -1.105686
#
#     Smoking  PhysicalActivity  DietQuality  SleepQuality  ...  \
# 0 -0.406355         -1.432099     0.160113      0.971063  ...
# 1 -0.406355          0.291269     0.453069     -1.076746  ...
# 2 -0.406355          0.581330     1.434458     -0.102976  ...
# 3 -0.406355         -1.256398     0.276233     -1.596880  ...
# 4 -0.406355         -0.154081    -0.651625      1.504976  ...
#
#    LungFunctionFVC  Wheezing  ShortnessOfBreath  ChestTightness  Coughing  \
# 0         0.920608 -1.214986          -1.000836        0.993333 -1.006711
# ...

# %% [markdown]
# ### Save the preprocessed data

# %%
save_path = "data/processed_asthma_data.csv"
save_data(df, save_path)
